# %% [markdown]
# <a href="https://colab.research.google.com/github/ella0065/ella0065/blob/main/%E4%BD%9C%E6%A5%AD8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/ella0065/ella0065/refs/heads/main/0109-1.csv"

# %%
df1 = pd.read_csv(url, index_col=0, encoding='unicode_escape')

# %%
df1
# Out:
#            YYYY/MM  Quarter consolidation  Month Currency  \
# CO_ID
# 5830 COTA  2023/12        4             N     12      NTD
# 5835 CUB   2023/12        4             Y     12      NTD
#
#            Total cash and cash equivalents  \
# CO_ID
# 5830 COTA                        2588203.0
# 5835 CUB                       105837938.0
#
#            Total due from the central bank and call loans to banks  \
# CO_ID
# 5830 COTA                                         11843735.0
# 5835 CUB                                         336768960.0
#
#            Total financial assets at fair value through profit or loss  \
# CO_ID
# 5830 COTA                                          5744901.0
# 5835 CUB                                         322291636.0
#
#            Derivative financial assets, net  \
# CO_ID
# 5830 COTA                               0.0
# 5835 CUB                                0.0
#
#            Securities purchased under resell agreements, net  ...  \
# ...

# %%
url = "https://raw.githubusercontent.com/ella0065/ella0065/refs/heads/main/0109-2.csv"

# %%
df2 = pd.read_csv(url, index_col=0, encoding='unicode_escape')

# %%
df2
# Out:
#            YYYY/MM  Quarter consolidation  Month Currency  \
# CO_ID
# 5830 COTA  2023/12        4             N     12      NTD
# 5835 CUB   2023/12        4             Y     12      NTD
#
#            Total interest income  Total interest expenses  \
# CO_ID
# 5830 COTA              4749934.0                1925346.0
# 5835 CUB             109474073.0               57730783.0
#
#            Net income (loss) of interest  Net non-interest income (loss)  \
# CO_ID
# 5830 COTA                      2824588.0                        551933.0
# 5835 CUB                      51743290.0                      35154540.0
#
#            Net service fee (charge) income (losses)  ...  \
# CO_ID                                                ...
# 5830 COTA                                  343106.0  ...
# 5835 CUB                                 20843725.0  ...
#
#            Comprehensive income, attributable to non-controlling interest in pre-aquisition  \
# CO_ID
# ...

# %%
df1.columns
# Out:
# Index(['YYYY/MM', 'Quarter', 'consolidation', 'Month', 'Currency',
#        'Total cash and cash equivalents',
#        'Total due from the central bank and call loans to banks',
#        'Total financial assets at fair value through profit or loss',
#        'Derivative financial assets, net',
#        'Securities purchased under resell agreements, net', 'Receivables, net',
#        'Total current tax assets', 'Assets classified as held for sale, net',
#        'Discounts and loans, net',
#        'Financial assets at fair value through other comprehensive income, net',
#        'Financial assets measured at amortized cost, net',
#        'Investments measured by equity method, net', 'Restricted assets, net',
#        'Other financial assets, net', 'Total property, plant and equipment',
#        'Right of use assets', 'Investment property, net',
#        'Intangible assets, net', 'Total deferred tax assets',
#        'Other assets, net', 'Total assets',
# ...

# %%
df1.index
# Out:
# Index(['5830 COTA', '5835 CUB'], dtype='object', name='CO_ID')

# %%
df2.columns
# Out:
# Index(['YYYY/MM', 'Quarter', 'consolidation', 'Month', 'Currency',
#        'Total interest income', 'Total interest expenses',
#        'Net income (loss) of interest', 'Net non-interest income (loss)',
#        'Net service fee (charge) income (losses)',
#        'Gain (loss) on fin. asset or liab. measured at fair value through profit or loss',
#        'Gain (loss) on fin. asset measured at fair value through OCI',
#        'Gain (loss) on financial assets measured at amortized cost',
#        'Gain (loss) on financial assets reclassification',
#        'Foreign exchange gain (loss)',
#        '(Impairment loss on assets) reversal of impairment loss on assets',
#        'Share of profit(loss) of associates &joint ventures accounted for using eq. meth',
#        'Net other non-interest income (loss)',
#        'Net income (loss) on hedging instrument, fair value hedges',
#        'Net income (loss) on hedged item attributable to hedged risk, fair value hedges',
# ...

# %%
df2.index
# Out:
# Index(['5830 COTA', '5835 CUB'], dtype='object', name='CO_ID')

# %%
A_5830 = (df1.loc['5830 COTA','Total cash and cash equivalents']-df1.loc['5830 COTA','Total payables'])/df1.loc['5830 COTA','Total assets']

# %%
A_5830
# Out:
# 0.00808348962726603

# %%
X1 ='Total cash and cash equivalents'
X2 ='Total payables'
X3 ='Total assets'
X4 ='Total retained earnings'
X5 ='Earnings Before Interest, Tax and Depreciation'
X6 ='Total equity'
X7 ='Total liabilities'
X8 ='Net non-interest income (loss)'
COTA ='5830 COTA'
CUB ='5835 CUB'

# %%
A_COTA = (df1.loc[COTA,X1] - df1.loc[COTA,X2])/df1.loc[COTA, X3]

# %%
B_COTA = df1.loc[COTA,X4]/df1.loc[COTA, X3]

# %%
C_COTA = df2.loc[COTA,X5]/df1.loc[COTA, X3]

# %%
D_COTA = df1.loc[COTA,X6]/df1.loc[COTA, X7]

# %%
E_COTA = df2.loc[COTA,X8]/df1.loc[COTA, X3]

# %%
Z_score_COTA = 1.2*A_COTA + 1.4*B_COTA + 3.3*C_COTA + 0.6*D_COTA +1.0*E_COTA

# %%
A_CUB = (df1.loc[CUB,X1] - df1.loc[CUB,X2])/df1.loc[CUB, X3]

# %%
B_CUB = df1.loc[CUB,X4]/df1.loc[CUB, X3]

# %%
C_CUB = df2.loc[CUB,X5]/df1.loc[CUB, X3]

# %%
D_CUB = df1.loc[CUB,X6]/df1.loc[CUB, X7]

# %%
E_CUB = df2.loc[CUB,X8]/df1.loc[CUB, X3]

# %%
Z_score_CUB = 1.2*A_CUB + 1.4*B_CUB + 3.3*C_CUB + 0.6*D_CUB +1.0*E_CUB

# %%
Z_score_CUB, A_CUB, B_CUB, C_CUB, D_CUB, E_CUB
# Out:
# (0.1875945134551405,
#  0.015145616780202103,
#  0.030852428625372054,
#  0.02306126659104249,
#  0.06970115371907787,
#  0.008303501261490182)
