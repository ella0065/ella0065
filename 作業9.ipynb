# %% [markdown]
# <a href="https://colab.research.google.com/github/ella0065/ella0065/blob/main/%E4%BD%9C%E6%A5%AD9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fredapi

# %%
from fredapi import Fred

# %%
fred = Fred(api_key='896def987414d9e41360bb0e8c96c561')

# %%
data1 = fred.get_series('SP500')

# %%
data1 = fred.get_series('SP500', '6/1/2024')

# %%
data1.plot()
# Out:
# <Axes: >

# %%
data2 = fred.get_series('RRPONTSYD')

# %%
data2 = fred.get_series('RRPONTSYD', '6/1/2024')

# %%
data1.plot()
data2.plot()
# Out:
# <Axes: >

# %%
df1 = data1.to_frame(name="SP500")
df2 = data2.to_frame(name='RRPONTSYD')

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
plt.plot(df_merged.index, df_merged['SP500'])
plt.plot(df_merged.index, df_merged['RRPONTSYD'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8d3123707335> in <cell line: 1>()
# ----> 1 plt.plot(df_merged.index, df_merged['SP500'])
#       2 plt.plot(df_merged.index, df_merged['RRPONTSYD'])
#
# NameError: name 'df_merged' is not defined
